# %% [markdown]
# <a href="https://colab.research.google.com/github/sathu0622/DL_Assigment/blob/feature%2Fabishek/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Introduction**
#
# In this section, a **basic Artificial Neural Network (ANN)** model is implemented using the Fashion MNIST dataset.
# The aim is to establish a simple baseline model for comparison with more complex architectures such as CNNs and augmented networks developed by other group members.
# An ANN is a feed-forward neural network composed of multiple fully connected layers, suitable for handling flattened image data without spatial hierarchy.

# %% [markdown]
# # **Importing Required Libraries**

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Flatten, Dense
from tensorflow.keras.datasets import fashion_mnist
import matplotlib.pyplot as plt

# %% [markdown]
# # **Loading and Preparing the Dataset**

# %%
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

# %% [markdown]
# # **Building the ANN Model**

# %%
model1 = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])

# %% [markdown]
# # **Compiling the Model**

# %%
model1.compile(optimizer='adam',
               loss='sparse_categorical_crossentropy',
               metrics=['accuracy'])

# %% [markdown]
# # **Training the Model**

# %%
history1 = model1.fit(x_train, y_train, epochs=10,
                      validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.7805 - loss: 0.6260 - val_accuracy: 0.8427 - val_loss: 0.4335
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8618 - loss: 0.3741 - val_accuracy: 0.8388 - val_loss: 0.4250
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8741 - loss: 0.3413 - val_accuracy: 0.8690 - val_loss: 0.3665
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8845 - loss: 0.3096 - val_accuracy: 0.8727 - val_loss: 0.3529
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8930 - loss: 0.2916 - val_accuracy: 0.8696 - val_loss: 0.3658
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8986 - loss: 0.2699 - val_accuracy: 0.8776 - val_loss: 0.3519
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9029 - loss: 0.2611 - val_accuracy: 0.8730 - val_loss: 0.3480
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9054 - loss: 0.2553 - val_accuracy: 0.8810 - val_loss: 0.3283
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9061 - loss: 0.2457 - val_accuracy: 0.8799 - val_loss: 0.3458
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9101 - loss: 0.2382 - val_accuracy: 0.8797 - val_loss: 0.3398

# %% [markdown]
# # **Model Evaluation**

# %%
test_loss, test_acc = model1.evaluate(x_test, y_test)
print(f"\nFinal Test Accuracy (ANN): {test_acc:.4f}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8815 - loss: 0.3381
#
# Final Test Accuracy (ANN): 0.8797

# %% [markdown]
# # **Visualizing Accuracy**

# %%
plt.figure(figsize=(8,4))
plt.plot(history1.history['accuracy'], label='Train Accuracy')
plt.plot(history1.history['val_accuracy'], label='Validation Accuracy')
plt.title("Member 1 - ANN Accuracy")
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
